# %%
import zapRun


zapRun.attack("https://stennickedata.dk/", "lol")
# Out:
# 'Create ZAP session: lol -> OK'
# Add Global Exclude URL regular expressions:
# '^(?:(?!http:\\/\\/localhost:8081).*).$ ->OK'
# 'Enable outgoing proxy chain: False -> OK'
# 'Enable all passive scanners -> OK'
# No custom policy used for scan
# 'Access target URL https://stennickedata.dk/'
# Starting Scans on target: https://stennickedata.dk/
# Scan ID equals 0
# Spider scan completed
# 'Start Ajax Spider -> OK'
# Ajax Spider is running
# Ajax Spider is running
# Ajax Spider scan completed
# Start Active scan. Scan ID equals 0
# Active Scan progress: 0%
# Active Scan progress: 9%
# Active Scan progress: 40%
# Active Scan progress: 49%
# Active Scan progress: 58%
# Active Scan progress: 70%
# Active Scan progress: 93%
# Active Scan completed
# [{'alert': 'Absence of Anti-CSRF Tokens',
#   'attack': '',
#   'confidence': 'Medium',
#   'cweid': '352',
#   'description': 'No Anti-CSRF tokens were found in a HTML submission form.\n'
# ...
